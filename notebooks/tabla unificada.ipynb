# %%
import asyncio

from joblib import Parallel, delayed

import requests as req
from bs4 import BeautifulSoup as bs

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options

import time
import multiprocessing as mp

import pandas as pd
pd.set_option('display.max_columns', None)  # me muestre todas las columnas
#pd.set_option('display.max_rows', None)  # me muestre todas las filas

from tqdm.notebook import tqdm

#from webdriver_manager.chrome import ChromeDriverManager
#PATH=ChromeDriverManager().install()

PATH=r'Chromedriver\chromedriver'

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Stats

# %%
stats_original = pd.read_csv(r'stats_first_clean.csv')
stats = stats_original.copy()
stats.head()
# Out:
#    Unnamed: 0                 name        username  \
# 0           0       Engine, Komodo     komodochess
# 1           1        Plát, Vojtěch     vojtechplat
# 2           2  Carlsen, PlayMagnus      playmagnus
# 3           3      Carlsen, Magnus   magnuscarlsen
# 4           4     Caruana, Fabiano  fabianocaruana
#
#                                        profile   user_id title    fide  \
# 0     https://www.chess.com/member/KomodoChess  24944922    GM  3411.0
# 1     https://www.chess.com/member/VojtechPlat  37712368    GM  2950.0
# 2      https://www.chess.com/member/PlayMagnus  19578862    GM  2882.0
# 3   https://www.chess.com/member/MagnusCarlsen   3889224    GM  2882.0
# 4  https://www.chess.com/member/FabianoCaruana  11177810    GM  2835.0
#
#           country  current_rapid_rating  highest_rapid_rating  rapid_win  \
# 0   United States                   NaN                   NaN        NaN
# 1  Czech Republic                2383.0                2672.0       12.0
# 2          Norway                   NaN                   NaN        NaN
# 3          Norway                2925.0                2977.0       43.0
# 4   United States                2794.0                3045.0      122.0
#
#    rapid_draw  rapid_loss  current_blitz_rating  highest_blitz_rating  \
# 0         NaN         NaN                   NaN                   NaN
# 1         5.0         6.0                2823.0                2914.0
# 2         NaN         NaN                   NaN                   NaN
# 3        23.0         8.0                3287.0                3322.0
# 4       103.0        46.0                3125.0                3136.0
#
#    blitz_win  blitz_draw  blitz_loss  current_bullet_rating  \
# 0        NaN         NaN         NaN                    NaN
# 1      976.0       280.0       847.0                 2661.0
# 2        NaN         NaN         NaN                    NaN
# 3     1402.0       292.0       334.0                 3249.0
# 4     1012.0       194.0       322.0                 3030.0
#
#    highest_bullet_rating  bullet_win  bullet_draw  bullet_loss
# 0                    NaN         NaN          NaN          NaN
# 1                 2750.0        32.0          8.0         47.0
# 2                    NaN         NaN          NaN          NaN
# 3                 3390.0       662.0         98.0        246.0
# 4                 3113.0       713.0         65.0        203.0

# %%
stats = stats.drop(['profile', 'user_id'], axis=1)
stats
# Out:
#       Unnamed: 0                 name          username title    fide  \
# 0              0       Engine, Komodo       komodochess    GM  3411.0
# 1              1        Plát, Vojtěch       vojtechplat    GM  2950.0
# 2              2  Carlsen, PlayMagnus        playmagnus    GM  2882.0
# 3              3      Carlsen, Magnus     magnuscarlsen    GM  2882.0
# 4              4     Caruana, Fabiano    fabianocaruana    GM  2835.0
# ...          ...                  ...               ...   ...     ...
# 1503        1503   Zvonko, Stanojoski             zona1    GM     NaN
# 1504        1504     Gurevich, Dmitry               zq1    GM     NaN
# 1505        1505     Zubov, Alexander   zubov_alexander    GM     NaN
# 1506        1506     Zubov, Alexander  zubov_on_youtube    GM     NaN
# 1507        1507       Diamant, Andre        zugazuando    GM     NaN
#
#               country  current_rapid_rating  highest_rapid_rating  rapid_win  \
# 0       United States                   NaN                   NaN        NaN
# 1      Czech Republic                2383.0                2672.0       12.0
# 2              Norway                   NaN                   NaN        NaN
# 3              Norway                2925.0                2977.0       43.0
# 4       United States                2794.0                3045.0      122.0
# ...               ...                   ...                   ...        ...
# 1503  North Macedonia                   NaN                   NaN        NaN
# 1504    United States                2375.0                2555.0        7.0
# 1505          Ukraine                   NaN                   NaN        NaN
# 1506          Ukraine                   NaN                   NaN        NaN
# 1507           Brazil                2346.0                2550.0      201.0
#
#       rapid_draw  rapid_loss  current_blitz_rating  highest_blitz_rating  \
# 0            NaN         NaN                   NaN                   NaN
# 1            5.0         6.0                2823.0                2914.0
# 2            NaN         NaN                   NaN                   NaN
# 3           23.0         8.0                3287.0                3322.0
# 4          103.0        46.0                3125.0                3136.0
# ...          ...         ...                   ...                   ...
# 1503         NaN         NaN                2375.0                2430.0
# 1504         2.0         6.0                2415.0                2675.0
# 1505         NaN         NaN                2961.0                2967.0
# 1506         NaN         NaN                2771.0                2763.0
# 1507        13.0        12.0                2613.0                2745.0
#
#       blitz_win  blitz_draw  blitz_loss  current_bullet_rating  \
# 0           NaN         NaN         NaN                    NaN
# 1         976.0       280.0       847.0                 2661.0
# 2           NaN         NaN         NaN                    NaN
# 3        1402.0       292.0       334.0                 3249.0
# 4        1012.0       194.0       322.0                 3030.0
# ...         ...         ...         ...                    ...
# 1503       50.0         9.0        27.0                 2102.0
# 1504     3293.0       538.0      2521.0                 2400.0
# 1505      338.0        22.0        96.0                    NaN
# 1506      138.0         3.0        11.0                    NaN
# 1507     1147.0       150.0       503.0                 1865.0
#
#       highest_bullet_rating  bullet_win  bullet_draw  bullet_loss
# 0                       NaN         NaN          NaN          NaN
# 1                    2750.0        32.0          8.0         47.0
# 2                       NaN         NaN          NaN          NaN
# 3                    3390.0       662.0         98.0        246.0
# 4                    3113.0       713.0         65.0        203.0
# ...                     ...         ...          ...          ...
# 1503                 2083.0        13.0          1.0          7.0
# 1504                 2594.0       496.0         47.0        402.0
# 1505                    NaN         NaN          NaN          NaN
# 1506                    NaN         NaN          NaN          NaN
# 1507                 2645.0       110.0         15.0         39.0
#
# [1508 rows x 21 columns]

# %% [markdown]
# # Df

# %%
df_original = pd.read_csv(r'top_100_scraping.csv')
df = df_original.copy()
df.head()
# Out:
#                 name            Wins          Draws          Losses
# 0    Carlsen, Magnus  2879 (48.53 %)  718 (35.27 %)    961 (16.2 %)
# 1   Caruana, Fabiano  2025 (42.75 %)  547 (34.49 %)  1078 (22.76 %)
# 2   Nakamura, Hikaru             NaN            NaN             NaN
# 3        Ding, Liren   760 (33.48 %)   413 (47.4 %)   434 (19.12 %)
# 4  Firouzja, Alireza  1484 (52.68 %)  223 (23.82 %)    662 (23.5 %)

# %% [markdown]
# ## compruebo si tengo los datos que me faltan en esta tabla

# %%
nombres_filtrados = []
for n in lst:
    filtro = df.loc[df['name'] == n]
    nombres_filtrados.append(filtro)
    
nombres_filtrados
# Out:
# [               name Wins Draws Losses
#  2  Nakamura, Hikaru  NaN   NaN    NaN,
#            name           Wins         Draws         Losses
#  3  Ding, Liren  760 (33.48 %)  413 (47.4 %)  434 (19.12 %),
#                  name            Wins          Draws        Losses
#  4  Firouzja, Alireza  1484 (52.68 %)  223 (23.82 %)  662 (23.5 %),
#                        name            Wins          Draws          Losses
#  15  Mamedyarov, Shakhriyar  2034 (41.27 %)  727 (37.32 %)  1055 (21.41 %),
#                name Wins Draws Losses
#  16  Le, Quang Liem  NaN   NaN    NaN,
#                     name            Wins          Draws        Losses
#  17  Grischuk, Alexander  2066 (39.41 %)  805 (41.68 %)  991 (18.9 %),
#                  name            Wins          Draws         Losses
#  20  Topalov, Veselin  1002 (33.71 %)  None (42.8 %)  698 (23.49 %),
#         name           Wins           Draws         Losses
#  21  Wei, Yi  704 (39.33 %)  None (41.62 %)  341 (19.05 %),
#                  name           Wins           Draws         Losses
#  23  Vitiugov, Nikita  898 (39.27 %)  None (45.65 %)  345 (15.09 %)]

# %% [markdown]
# ## Nos faltan los datos de (Le, Quang Liem) y ( Nakamura, Hikaru)

# %%
# Lo puedo pillar a mano o escrapear sus nombres

# %% [markdown]
# # Table

# %%
table_original = pd.read_csv(r'rating_top_100.csv')
table = table_original.copy()
table.head()
# Out:
#    #               Name  Classic   Rapid   Blitz  Age
# 0  1    Carlsen, Magnus   2838.4  2825.0  2887.0   32
# 1  2   Caruana, Fabiano   2782.6  2767.4  2813.0   31
# 2  3   Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 3  4        Ding, Liren   2780.0  2830.0  2787 i   30
# 4  5  Firouzja, Alireza   2777.0  2742.0  2896.0   20

# %%
table.columns = ['#', 'name', 'Classic', 'Rapid', 'Blitz', 'Age']
table
# Out:
#       #                        name  Classic   Rapid   Blitz  Age
# 0     1             Carlsen, Magnus   2838.4  2825.0  2887.0   32
# 1     2            Caruana, Fabiano   2782.6  2767.4  2813.0   31
# 2     3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 3     4                 Ding, Liren   2780.0  2830.0  2787 i   30
# 4     5           Firouzja, Alireza   2777.0  2742.0  2896.0   20
# ..  ...                         ...      ...     ...     ...  ...
# 95   96              Najer, Evgeniy   2648.0  2579.0  2545.0   46
# 96   97                 Saric, Ivan   2647.5  2631.0  2586.0   32
# 97   98          Malakhov, Vladimir   2646.0  2666.0  2652.0   42
# 98   99              Liang, Awonder   2645.6  2518.4  2538.0   20
# 99  100  Aravindh, Chithambaram VR.   2645.0  2553.0  2596.0   23
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Merge

# %%
table = pd.merge(table, df, on='name', how='left')
table
# Out:
#       #                        name  Classic   Rapid   Blitz  Age  \
# 0     1             Carlsen, Magnus   2838.4  2825.0  2887.0   32
# 1     2            Caruana, Fabiano   2782.6  2767.4  2813.0   31
# 2     3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 3     4                 Ding, Liren   2780.0  2830.0  2787 i   30
# 4     5           Firouzja, Alireza   2777.0  2742.0  2896.0   20
# ..  ...                         ...      ...     ...     ...  ...
# 95   96              Najer, Evgeniy   2648.0  2579.0  2545.0   46
# 96   97                 Saric, Ivan   2647.5  2631.0  2586.0   32
# 97   98          Malakhov, Vladimir   2646.0  2666.0  2652.0   42
# 98   99              Liang, Awonder   2645.6  2518.4  2538.0   20
# 99  100  Aravindh, Chithambaram VR.   2645.0  2553.0  2596.0   23
#
#               Wins           Draws          Losses
# 0   2879 (48.53 %)   718 (35.27 %)    961 (16.2 %)
# 1   2025 (42.75 %)   547 (34.49 %)  1078 (22.76 %)
# 2              NaN             NaN             NaN
# 3    760 (33.48 %)    413 (47.4 %)   434 (19.12 %)
# 4   1484 (52.68 %)   223 (23.82 %)    662 (23.5 %)
# ..             ...             ...             ...
# 95  1181 (43.18 %)  None (34.52 %)    610 (22.3 %)
# 96  1153 (43.31 %)  None (36.03 %)   550 (20.66 %)
# 97             NaN             NaN             NaN
# 98             NaN             NaN             NaN
# 99             NaN             NaN             NaN
#
# [100 rows x 9 columns]

# %%
table = pd.merge(table, stats, on='name', how='left')
table
# Out:
#        #                        name  Classic   Rapid   Blitz  Age  \
# 0      1             Carlsen, Magnus   2838.4  2825.0  2887.0   32
# 1      2            Caruana, Fabiano   2782.6  2767.4  2813.0   31
# 2      3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 3      3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 4      3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# ..   ...                         ...      ...     ...     ...  ...
# 111   96              Najer, Evgeniy   2648.0  2579.0  2545.0   46
# 112   97                 Saric, Ivan   2647.5  2631.0  2586.0   32
# 113   98          Malakhov, Vladimir   2646.0  2666.0  2652.0   42
# 114   99              Liang, Awonder   2645.6  2518.4  2538.0   20
# 115  100  Aravindh, Chithambaram VR.   2645.0  2553.0  2596.0   23
#
#                Wins           Draws          Losses  Unnamed: 0  \
# 0    2879 (48.53 %)   718 (35.27 %)    961 (16.2 %)         3.0
# 1    2025 (42.75 %)   547 (34.49 %)  1078 (22.76 %)         4.0
# 2               NaN             NaN             NaN         6.0
# 3               NaN             NaN             NaN        11.0
# 4               NaN             NaN             NaN        29.0
# ..              ...             ...             ...         ...
# 111  1181 (43.18 %)  None (34.52 %)    610 (22.3 %)      1096.0
# 112  1153 (43.31 %)  None (36.03 %)   550 (20.66 %)       101.0
# 113             NaN             NaN             NaN       117.0
# 114             NaN             NaN             NaN      1379.0
# 115             NaN             NaN             NaN         NaN
#
#              username title    fide        country  current_rapid_rating  \
# 0       magnuscarlsen    GM  2882.0         Norway                2925.0
# 1      fabianocaruana    GM  2835.0  United States                2794.0
# 2              hikaru    GM  2814.0  United States                2781.0
# 3    gmnakamuracyborg    GM  2785.0  United States                 263.0
# 4      hikarunakamura    GM  2729.0  United States                   NaN
# ..                ...   ...     ...            ...                   ...
# 111          enajer77    GM     NaN         Russia                2446.0
# 112     dalmatinac101    GM  2660.0        Croatia                2712.0
# 113     vladimir_2020    GM  2650.0         Russia                2556.0
# 114       rednova1729    GM     NaN  United States                2600.0
# 115               NaN   NaN     NaN            NaN                   NaN
#
#      highest_rapid_rating  rapid_win  rapid_draw  rapid_loss  \
# 0                  2977.0       43.0        23.0         8.0
# 1                  3045.0      122.0       103.0        46.0
# 2                  2927.0      156.0       157.0        39.0
# 3                     NaN        0.0         0.0         1.0
# 4                     NaN        NaN         NaN         NaN
# ..                    ...        ...         ...         ...
# 111                2530.0       18.0        12.0        15.0
# 112                2870.0       31.0        21.0        17.0
# 113                2785.0       49.0        15.0        15.0
# 114                2765.0       33.0         5.0         9.0
# 115                   NaN        NaN         NaN         NaN
#
#      current_blitz_rating  highest_blitz_rating  blitz_win  blitz_draw  \
# 0                  3287.0                3322.0     1402.0       292.0
# 1                  3125.0                3136.0     1012.0       194.0
# 2                  3232.0                3332.0    24782.0      3307.0
# 3                     NaN                   NaN        NaN         NaN
# 4                     NaN                   NaN        NaN         NaN
# ..                    ...                   ...        ...         ...
# 111                2842.0                2842.0      397.0        62.0
# 112                2820.0                3016.0     1992.0       656.0
# 113                   NaN                   NaN        NaN         NaN
# 114                3035.0                3042.0      563.0       165.0
# 115                   NaN                   NaN        NaN         NaN
#
#      blitz_loss  current_bullet_rating  highest_bullet_rating  bullet_win  \
# 0         334.0                 3249.0                 3390.0       662.0
# 1         322.0                 3030.0                 3113.0       713.0
# 2        4284.0                 3326.0                 3570.0     10920.0
# 3           NaN                    NaN                    NaN         NaN
# 4           NaN                    NaN                    NaN         NaN
# ..          ...                    ...                    ...         ...
# 111       323.0                 2558.0                 2576.0         1.0
# 112      1527.0                 3098.0                 3109.0       221.0
# 113         NaN                    NaN                    NaN         NaN
# 114       397.0                 3040.0                 3082.0      1163.0
# 115         NaN                    NaN                    NaN         NaN
#
#      bullet_draw  bullet_loss
# 0           98.0        246.0
# 1           65.0        203.0
# 2          659.0       1536.0
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 111          0.0          2.0
# 112         21.0        125.0
# 113          NaN          NaN
# 114        167.0        787.0
# 115          NaN          NaN
#
# [116 rows x 29 columns]

# %%
table = table.drop_duplicates()
table
# Out:
#        #                        name  Classic   Rapid   Blitz  Age  \
# 0      1             Carlsen, Magnus   2838.4  2825.0  2887.0   32
# 1      2            Caruana, Fabiano   2782.6  2767.4  2813.0   31
# 2      3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 3      3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# 4      3            Nakamura, Hikaru   2782.6  2744.8  2874.0   35
# ..   ...                         ...      ...     ...     ...  ...
# 111   96              Najer, Evgeniy   2648.0  2579.0  2545.0   46
# 112   97                 Saric, Ivan   2647.5  2631.0  2586.0   32
# 113   98          Malakhov, Vladimir   2646.0  2666.0  2652.0   42
# 114   99              Liang, Awonder   2645.6  2518.4  2538.0   20
# 115  100  Aravindh, Chithambaram VR.   2645.0  2553.0  2596.0   23
#
#                Wins           Draws          Losses  Unnamed: 0  \
# 0    2879 (48.53 %)   718 (35.27 %)    961 (16.2 %)         3.0
# 1    2025 (42.75 %)   547 (34.49 %)  1078 (22.76 %)         4.0
# 2               NaN             NaN             NaN         6.0
# 3               NaN             NaN             NaN        11.0
# 4               NaN             NaN             NaN        29.0
# ..              ...             ...             ...         ...
# 111  1181 (43.18 %)  None (34.52 %)    610 (22.3 %)      1096.0
# 112  1153 (43.31 %)  None (36.03 %)   550 (20.66 %)       101.0
# 113             NaN             NaN             NaN       117.0
# 114             NaN             NaN             NaN      1379.0
# 115             NaN             NaN             NaN         NaN
#
#              username title    fide        country  current_rapid_rating  \
# 0       magnuscarlsen    GM  2882.0         Norway                2925.0
# 1      fabianocaruana    GM  2835.0  United States                2794.0
# 2              hikaru    GM  2814.0  United States                2781.0
# 3    gmnakamuracyborg    GM  2785.0  United States                 263.0
# 4      hikarunakamura    GM  2729.0  United States                   NaN
# ..                ...   ...     ...            ...                   ...
# 111          enajer77    GM     NaN         Russia                2446.0
# 112     dalmatinac101    GM  2660.0        Croatia                2712.0
# 113     vladimir_2020    GM  2650.0         Russia                2556.0
# 114       rednova1729    GM     NaN  United States                2600.0
# 115               NaN   NaN     NaN            NaN                   NaN
#
#      highest_rapid_rating  rapid_win  rapid_draw  rapid_loss  \
# 0                  2977.0       43.0        23.0         8.0
# 1                  3045.0      122.0       103.0        46.0
# 2                  2927.0      156.0       157.0        39.0
# 3                     NaN        0.0         0.0         1.0
# 4                     NaN        NaN         NaN         NaN
# ..                    ...        ...         ...         ...
# 111                2530.0       18.0        12.0        15.0
# 112                2870.0       31.0        21.0        17.0
# 113                2785.0       49.0        15.0        15.0
# 114                2765.0       33.0         5.0         9.0
# 115                   NaN        NaN         NaN         NaN
#
#      current_blitz_rating  highest_blitz_rating  blitz_win  blitz_draw  \
# 0                  3287.0                3322.0     1402.0       292.0
# 1                  3125.0                3136.0     1012.0       194.0
# 2                  3232.0                3332.0    24782.0      3307.0
# 3                     NaN                   NaN        NaN         NaN
# 4                     NaN                   NaN        NaN         NaN
# ..                    ...                   ...        ...         ...
# 111                2842.0                2842.0      397.0        62.0
# 112                2820.0                3016.0     1992.0       656.0
# 113                   NaN                   NaN        NaN         NaN
# 114                3035.0                3042.0      563.0       165.0
# 115                   NaN                   NaN        NaN         NaN
#
#      blitz_loss  current_bullet_rating  highest_bullet_rating  bullet_win  \
# 0         334.0                 3249.0                 3390.0       662.0
# 1         322.0                 3030.0                 3113.0       713.0
# 2        4284.0                 3326.0                 3570.0     10920.0
# 3           NaN                    NaN                    NaN         NaN
# 4           NaN                    NaN                    NaN         NaN
# ..          ...                    ...                    ...         ...
# 111       323.0                 2558.0                 2576.0         1.0
# 112      1527.0                 3098.0                 3109.0       221.0
# 113         NaN                    NaN                    NaN         NaN
# 114       397.0                 3040.0                 3082.0      1163.0
# 115         NaN                    NaN                    NaN         NaN
#
#      bullet_draw  bullet_loss
# 0           98.0        246.0
# 1           65.0        203.0
# 2          659.0       1536.0
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 111          0.0          2.0
# 112         21.0        125.0
# 113          NaN          NaN
# 114        167.0        787.0
# 115          NaN          NaN
#
# [116 rows x 29 columns]

# %%
table.to_csv(r'final_table.csv', index=False)

# %% [markdown]
# # nuevo escraping

# %%
top_100 = table['name'].tolist()

# %%
# Función para obtener las estadísticas de un jugador
def obtener_estadisticas(jugador):
    driver = webdriver.Chrome(PATH, options=opciones)
    driver.get(url)
    time.sleep(3)

    # Aceptar cookies
    aceptar = driver.find_element(By.XPATH, '//*[@id="ez-accept-necessary"]')
    aceptar.click()
    
    # Variables de asignación predeterminadas
    wins = 'N/A'
    draws = 'N/A'
    losses = 'N/A'
    
    try:
        # Introducir el nombre del jugador
        texto = driver.find_element(By.XPATH, '//*[@id="data"]')
        texto.send_keys(jugador)
        texto.send_keys(Keys.ENTER)
        time.sleep(3)

        # Obtener las estadísticas
        wins = driver.find_element(By.XPATH, '//*[@id="about"]/div[1]/div[9]/div/h6').text
        draws = driver.find_element(By.XPATH, '//*[@id="about"]/div[1]/div[10]/div/h6').text
        losses = driver.find_element(By.XPATH, '//*[@id="about"]/div[1]/div[11]/div/h6').text

        driver.quit()  # Cerrar el navegador
        
    except:
        time.sleep(2)

    return {'Jugador': jugador, 'Wins': wins, 'Draws': draws, 'Losses': losses}

# URL y opciones del driver
url = 'https://www.yottachess.com/'
# PATH ya definido
opciones = webdriver.ChromeOptions()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

# Lista de jugadores top 100
# top_100 ya creada

# Realizar el procesamiento en paralelo para obtener las estadísticas de los jugadores
paralelo = Parallel(n_jobs=3,  verbose=True)
resultados = paralelo(delayed(obtener_estadisticas)(jugador) for jugador in tqdm(top_100))


# Crear el DataFrame con los resultados
data = pd.DataFrame(resultados)

# Mostrar el DataFrame
data
# Out:
#   0%|          | 0/116 [00:00<?, ?it/s]
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=3)]: Done 116 out of 116 | elapsed: 34.3min finished
#                         Jugador            Wins           Draws  \
# 0               Carlsen, Magnus  2879 (48.53 %)   718 (35.27 %)
# 1              Caruana, Fabiano  2025 (42.75 %)   547 (34.49 %)
# 2              Nakamura, Hikaru             N/A             N/A
# 3              Nakamura, Hikaru  3953 (51.91 %)   1107 (31.9 %)
# 4              Nakamura, Hikaru  3953 (51.91 %)   1107 (31.9 %)
# ..                          ...             ...             ...
# 111              Najer, Evgeniy  1181 (43.18 %)  None (34.52 %)
# 112                 Saric, Ivan  1153 (43.31 %)  None (36.03 %)
# 113          Malakhov, Vladimir   919 (41.03 %)  None (44.29 %)
# 114              Liang, Awonder   530 (44.17 %)   None (29.0 %)
# 115  Aravindh, Chithambaram VR.     163 (8.7 %)  None (23.28 %)
#
#              Losses
# 0      961 (16.2 %)
# 1    1078 (22.76 %)
# 2               N/A
# 3    1233 (16.19 %)
# 4    1233 (16.19 %)
# ..              ...
# 111    610 (22.3 %)
# 112   550 (20.66 %)
# 113   329 (14.69 %)
# 114   322 (26.83 %)
# 115  1274 (68.02 %)
#
# [116 rows x 4 columns]

# %%
data = data.drop_duplicates()
data
# Out:
#                         Jugador            Wins           Draws  \
# 0               Carlsen, Magnus  2879 (48.53 %)   718 (35.27 %)
# 1              Caruana, Fabiano  2025 (42.75 %)   547 (34.49 %)
# 2              Nakamura, Hikaru             N/A             N/A
# 3              Nakamura, Hikaru  3953 (51.91 %)   1107 (31.9 %)
# 6                   Ding, Liren             N/A             N/A
# ..                          ...             ...             ...
# 111              Najer, Evgeniy  1181 (43.18 %)  None (34.52 %)
# 112                 Saric, Ivan  1153 (43.31 %)  None (36.03 %)
# 113          Malakhov, Vladimir   919 (41.03 %)  None (44.29 %)
# 114              Liang, Awonder   530 (44.17 %)   None (29.0 %)
# 115  Aravindh, Chithambaram VR.     163 (8.7 %)  None (23.28 %)
#
#              Losses
# 0      961 (16.2 %)
# 1    1078 (22.76 %)
# 2               N/A
# 3    1233 (16.19 %)
# 6               N/A
# ..              ...
# 111    610 (22.3 %)
# 112   550 (20.66 %)
# 113   329 (14.69 %)
# 114   322 (26.83 %)
# 115  1274 (68.02 %)
#
# [102 rows x 4 columns]

# %%
data.to_csv(r'escrapeo_top_100.csv', index=False)

# %%
data.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 115
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jugador  102 non-null    object
#  1   Wins     102 non-null    object
#  2   Draws    102 non-null    object
#  3   Losses   102 non-null    object
# dtypes: object(4)
# memory usage: 28.8 KB

# %%
data.columns = ['name', 'Wins', 'Draws', 'Losses']
data
# Out:
#                            name            Wins           Draws  \
# 0               Carlsen, Magnus  2879 (48.53 %)   718 (35.27 %)
# 1              Caruana, Fabiano  2025 (42.75 %)   547 (34.49 %)
# 2              Nakamura, Hikaru             N/A             N/A
# 3              Nakamura, Hikaru  3953 (51.91 %)   1107 (31.9 %)
# 6                   Ding, Liren             N/A             N/A
# ..                          ...             ...             ...
# 111              Najer, Evgeniy  1181 (43.18 %)  None (34.52 %)
# 112                 Saric, Ivan  1153 (43.31 %)  None (36.03 %)
# 113          Malakhov, Vladimir   919 (41.03 %)  None (44.29 %)
# 114              Liang, Awonder   530 (44.17 %)   None (29.0 %)
# 115  Aravindh, Chithambaram VR.     163 (8.7 %)  None (23.28 %)
#
#              Losses
# 0      961 (16.2 %)
# 1    1078 (22.76 %)
# 2               N/A
# 3    1233 (16.19 %)
# 6               N/A
# ..              ...
# 111    610 (22.3 %)
# 112   550 (20.66 %)
# 113   329 (14.69 %)
# 114   322 (26.83 %)
# 115  1274 (68.02 %)
#
# [102 rows x 4 columns]

# %% [markdown]
# ## Miro por qué aparecen dos filas más de las que deberían

# %%
data.name.unique()
# Out:
# array(['Carlsen, Magnus', 'Caruana, Fabiano', 'Nakamura, Hikaru',
#        'Ding, Liren', 'Firouzja, Alireza', 'Nepomniachtchi, Ian',
#        'So, Wesley', 'Giri, Anish', 'Gukesh D', 'Anand, Viswanathan',
#        'Rapport, Richard', 'Karjakin, Sergey', 'Dominguez Perez, Leinier',
#        'Radjabov, Teimour', 'Aronian, Levon', 'Mamedyarov, Shakhriyar',
#        'Le, Quang Liem', 'Grischuk, Alexander', 'Duda, Jan-Krzysztof',
#        'Vachier-Lagrave, Maxime', 'Topalov, Veselin', 'Wei, Yi',
#        'Yu, Yangyi', 'Vitiugov, Nikita', 'Vidit, Santosh Gujrathi',
#        'Abdusattorov, Nodirbek', 'Praggnanandhaa R', 'Keymer, Vincent',
#        'Vallejo Pons, Francisco', 'Harikrishna, Pentala', 'Dubov, Daniil',
#        'Maghsoodloo, Parham', 'Sjugirov, Sanan', 'Erigaisi Arjun',
#        'Deac, Bogdan-Daniel', 'Robson, Ray', 'Wang, Hao',
#        'Van Foreest, Jorden', 'Artemiev, Vladislav', 'Sevian, Samuel',
#        'Shankland, Sam', 'Eljanov, Pavel', 'Tomashevsky, Evgeny',
#        'Xiong, Jeffery', 'Sargissian, Gabriel', 'Nihal Sarin',
#        'Svidler, Peter', 'Bu, Xiangzhi', 'Sarana, Alexey',
#        'Navara, David', 'Anton Guijarro, David', 'Tabatabaei, M. Amin',
#        'Martirosyan, Haik M.', 'Esipenko, Andrey', 'Amin, Bassem',
#        'Grandelius, Nils', 'Oparin, Grigoriy', 'Donchenko, Alexander',
#        'Shevchenko, Kirill', 'Matlakov, Maxim', 'Shirov, Alexei',
#        'Howell, David W L', 'Alekseenko, Kirill', 'Kovalenko, Igor',
#        'Wojtaszek, Radoslaw', 'Kasimdzhanov, Rustam', 'Ivanchuk, Vasyl',
#        'Fedoseev, Vladimir', 'Bluebaum, Matthias', 'Sindarov, Javokhir',
#        'Leko, Peter', 'Moussard, Jules', 'Bacrot, Etienne',
#        'Adams, Michael', 'Niemann, Hans Moke', 'Korobov, Anton',
#        'Volokitin, Andrei', 'Santos Latasa, Jaime', 'Wang, Yue',
#        'Narayanan.S.L', 'Inarkiev, Ernesto', 'Salem, A.R. Saleh',
#        'Kryvoruchko, Yuriy', 'Gelfand, Boris', 'Cheparinov, Ivan',
#        'Guseinov, Gadir', 'Abasov, Nijat', 'Fressinet, Laurent',
#        'Predke, Alexandr', 'Li, Chao b', 'Ma, Qun', 'Naiditsch, Arkadij',
#        'Ni, Hua', 'Ponomariov, Ruslan', 'Melkumyan, Hrant',
#        'Najer, Evgeniy', 'Saric, Ivan', 'Malakhov, Vladimir',
#        'Liang, Awonder', 'Aravindh, Chithambaram VR.'], dtype=object)

# %% [markdown]
# # Encontrar los valores que nos faltan

# %% [markdown]
# ## Columna wins

# %%
data['Wins'].unique()
# Out:
# array(['2879 (48.53 %)', '2025 (42.75 %)', 'N/A', '3953 (51.91 %)',
#        '1566 (40.26 %)', '1588 (39.11 %)', '1226 (32.51 %)',
#        '572 (30.94 %)', '1722 (36.44 %)', '864 (41.14 %)',
#        '1491 (38.17 %)', '982 (33.91 %)', '739 (29.01 %)',
#        '1765 (34.29 %)', '2034 (41.27 %)', '1440 (47.06 %)',
#        '1993 (41.44 %)', '1016 (42.05 %)', '1161 (43.61 %)',
#        '1278 (50.08 %)', '608 (28.64 %)', '1088 (50.07 %)',
#        '1229 (39.92 %)', '7 (25.0 %)', '1710 (47.9 %)', '1545 (52.59 %)',
#        '2097 (50.05 %)', '767 (32.31 %)', '1650 (53.48 %)',
#        '630 (42.42 %)', '890 (38.75 %)', '1312 (45.59 %)',
#        '1390 (48.72 %)', '1044 (46.92 %)', '315 (17.66 %)',
#        '1298 (42.29 %)', '733 (34.69 %)', '1834 (52.19 %)',
#        '875 (38.58 %)', '689 (29.13 %)', '1701 (37.29 %)',
#        '821 (39.04 %)', '2736 (56.03 %)', '1809 (47.46 %)',
#        '1239 (45.19 %)', '610 (50.75 %)', '903 (49.02 %)',
#        '1075 (46.3 %)', '1088 (49.79 %)', '1377 (44.84 %)',
#        '1688 (45.98 %)', '1528 (46.96 %)', '974 (50.54 %)',
#        '1525 (45.89 %)', '2392 (44.97 %)', '1471 (49.25 %)',
#        '1173 (51.33 %)', '1451 (52.46 %)', '1239 (41.55 %)',
#        '748 (38.4 %)', '232 (4.47 %)', '2228 (52.24 %)', '2061 (51.5 %)',
#        '497 (48.97 %)', '752 (25.45 %)', '1046 (52.96 %)',
#        '1910 (43.96 %)', '1569 (39.51 %)', '923 (49.15 %)',
#        '1675 (49.38 %)', '814 (39.57 %)', '779 (48.57 %)', '0 (0 %)',
#        '773 (36.6 %)', '899 (38.68 %)', '1076 (50.12 %)', '659 (39.99 %)',
#        '1326 (30.67 %)', '1273 (43.31 %)', '1194 (46.03 %)',
#        '543 (37.5 %)', '1410 (41.94 %)', '857 (46.42 %)', '652 (43.06 %)',
#        '234 (39.26 %)', '1411 (46.05 %)', '691 (39.94 %)',
#        '912 (34.98 %)', '1147 (48.7 %)', '1181 (43.18 %)',
#        '1153 (43.31 %)', '919 (41.03 %)', '530 (44.17 %)', '163 (8.7 %)'],
#       dtype=object)

# %%
len(data['Wins'].unique())
# Out:
# 94

# %%
Wins_filtradas = data.loc[data['Wins'] == 'N/A']
Wins_filtradas
# Out:
#                       name Wins Draws Losses
# 2         Nakamura, Hikaru  N/A   N/A    N/A
# 6              Ding, Liren  N/A   N/A    N/A
# 7        Firouzja, Alireza  N/A   N/A    N/A
# 22  Mamedyarov, Shakhriyar  N/A   N/A    N/A
# 26          Le, Quang Liem  N/A   N/A    N/A
# 27     Grischuk, Alexander  N/A   N/A    N/A
# 30        Topalov, Veselin  N/A   N/A    N/A
# 31                 Wei, Yi  N/A   N/A    N/A
# 33        Vitiugov, Nikita  N/A   N/A    N/A

# %%
lst = list(Wins_filtradas.name)
lst
# Out:
# ['Nakamura, Hikaru',
#  'Ding, Liren',
#  'Firouzja, Alireza',
#  'Mamedyarov, Shakhriyar',
#  'Le, Quang Liem',
#  'Grischuk, Alexander',
#  'Topalov, Veselin',
#  'Wei, Yi',
#  'Vitiugov, Nikita']

# %% [markdown]
# ## Columna draws

# %%
data['Draws'].unique()
# Out:
# array(['718 (35.27 %)', '547 (34.49 %)', 'N/A', '1107 (31.9 %)',
#        '589 (39.02 %)', '586 (43.79 %)', '688 (48.02 %)',
#        'None (22.01 %)', '956 (48.8 %)', '274 (37.0 %)', '694 (42.29 %)',
#        '516 (44.99 %)', '574 (53.4 %)', '822 (45.23 %)', '727 (37.32 %)',
#        '0 (29.84 %)', 'None (40.69 %)', '382 (42.14 %)', 'None (36.33 %)',
#        '176 (25.47 %)', 'None (24.45 %)', '240 (23.06 %)',
#        'None (38.75 %)', '4 (60.71 %)', '505 (31.9 %)', 'None (24.13 %)',
#        'None (26.35 %)', '164 (24.77 %)', 'None (25.71 %)',
#        'None (32.39 %)', '801 (41.84 %)', '295 (28.49 %)',
#        '386 (34.74 %)', 'None (31.33 %)', 'None (38.51 %)',
#        'None (34.96 %)', 'None (50.5 %)', 'None (27.4 %)',
#        'None (46.08 %)', '307 (32.05 %)', 'None (44.31 %)',
#        '491 (47.03 %)', 'None (20.6 %)', 'None (33.63 %)',
#        'None (33.41 %)', 'None (23.96 %)', '102 (28.66 %)',
#        'None (33.33 %)', '345 (27.0 %)', 'None (34.03 %)',
#        'None (30.12 %)', '184 (26.41 %)', 'None (35.06 %)',
#        '1032 (37.0 %)', 'None (28.26 %)', 'None (22.67 %)',
#        '301 (25.05 %)', '493 (42.69 %)', 'None (44.1 %)', '155 (44.49 %)',
#        'None (23.77 %)', 'None (26.19 %)', 'None (28.08 %)',
#        'None (57.87 %)', '155 (24.15 %)', '790 (36.16 %)',
#        'None (45.33 %)', '144 (22.31 %)', '486 (31.84 %)',
#        'None (39.04 %)', 'None (35.41 %)', 'None (0 %)', '155 (29.12 %)',
#        'None (39.11 %)', 'None (23.47 %)', 'None (46.18 %)',
#        'None (50.53 %)', 'None (38.86 %)', 'None (33.27 %)',
#        'None (42.47 %)', 'None (39.77 %)', 'None (31.64 %)',
#        'None (39.5 %)', 'None (47.48 %)', 'None (31.89 %)',
#        'None (45.2 %)', '500 (45.15 %)', 'None (27.77 %)',
#        'None (34.52 %)', 'None (36.03 %)', 'None (44.29 %)',
#        'None (29.0 %)', 'None (23.28 %)'], dtype=object)

# %%
len(data['Draws'].unique())
# Out:
# 93

# %%
Draws_filtradas = data.loc[data['Draws'] == 'N/A']
Draws_filtradas
# Out:
#                       name Wins Draws Losses
# 2         Nakamura, Hikaru  N/A   N/A    N/A
# 6              Ding, Liren  N/A   N/A    N/A
# 7        Firouzja, Alireza  N/A   N/A    N/A
# 22  Mamedyarov, Shakhriyar  N/A   N/A    N/A
# 26          Le, Quang Liem  N/A   N/A    N/A
# 27     Grischuk, Alexander  N/A   N/A    N/A
# 30        Topalov, Veselin  N/A   N/A    N/A
# 31                 Wei, Yi  N/A   N/A    N/A
# 33        Vitiugov, Nikita  N/A   N/A    N/A

# %% [markdown]
# ## Columna losses

# %%
data['Losses'].unique()
# Out:
# array(['961 (16.2 %)', '1078 (22.76 %)', 'N/A', '1233 (16.19 %)',
#        '806 (20.72 %)', '694 (17.09 %)', '734 (19.46 %)', '870 (47.05 %)',
#        '697 (14.75 %)', '459 (21.86 %)', '763 (19.53 %)', '611 (21.1 %)',
#        '448 (17.59 %)', '1054 (20.48 %)', '1055 (21.41 %)',
#        '707 (23.1 %)', '859 (17.86 %)', '382 (15.81 %)', '534 (20.06 %)',
#        '624 (24.45 %)', '996 (46.91 %)', '584 (26.88 %)', '657 (21.34 %)',
#        '4 (14.29 %)', '721 (20.2 %)', '684 (23.28 %)', '989 (23.6 %)',
#        '1019 (42.92 %)', '642 (20.81 %)', '374 (25.19 %)',
#        '446 (19.42 %)', '746 (25.92 %)', '472 (16.54 %)', '484 (21.75 %)',
#        '782 (43.83 %)', '698 (22.74 %)', '313 (14.81 %)', '717 (20.4 %)',
#        '348 (15.34 %)', '918 (38.82 %)', '839 (18.4 %)', '293 (13.93 %)',
#        '1141 (23.37 %)', '721 (18.91 %)', '587 (21.41 %)',
#        '304 (25.29 %)', '411 (22.31 %)', '473 (20.37 %)', '507 (23.2 %)',
#        '649 (21.13 %)', '794 (21.63 %)', '746 (22.93 %)', '444 (23.04 %)',
#        '633 (19.05 %)', '959 (18.03 %)', '672 (22.5 %)', '594 (26.0 %)',
#        '622 (22.49 %)', '470 (15.76 %)', '341 (17.51 %)',
#        '2651 (51.04 %)', '1023 (23.99 %)', '893 (22.31 %)',
#        '233 (22.96 %)', '493 (16.68 %)', '452 (22.89 %)', '864 (19.88 %)',
#        '602 (15.16 %)', '536 (28.54 %)', '637 (18.78 %)', '440 (21.39 %)',
#        '257 (16.02 %)', '0 (0 %)', '724 (34.28 %)', '516 (22.2 %)',
#        '567 (26.41 %)', '228 (13.83 %)', '813 (18.8 %)', '524 (17.83 %)',
#        '537 (20.7 %)', '290 (20.03 %)', '615 (18.29 %)', '405 (21.94 %)',
#        '264 (17.44 %)', '79 (13.26 %)', '676 (22.06 %)', '257 (14.86 %)',
#        '518 (19.87 %)', '554 (23.52 %)', '610 (22.3 %)', '550 (20.66 %)',
#        '329 (14.69 %)', '322 (26.83 %)', '1274 (68.02 %)'], dtype=object)

# %%
len(data['Losses'].unique())
# Out:
# 94

# %%
Losses_filtradas = data.loc[data['Losses'] == 'N/A']
Losses_filtradas
# Out:
#                       name Wins Draws Losses
# 2         Nakamura, Hikaru  N/A   N/A    N/A
# 6              Ding, Liren  N/A   N/A    N/A
# 7        Firouzja, Alireza  N/A   N/A    N/A
# 22  Mamedyarov, Shakhriyar  N/A   N/A    N/A
# 26          Le, Quang Liem  N/A   N/A    N/A
# 27     Grischuk, Alexander  N/A   N/A    N/A
# 30        Topalov, Veselin  N/A   N/A    N/A
# 31                 Wei, Yi  N/A   N/A    N/A
# 33        Vitiugov, Nikita  N/A   N/A    N/A
